# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/2_08_Pandas Concat DataFrames.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## 🟩 Concat Job Postings (2.8.1)

# %%
df_data_analyst = df[df['job_title'] == 'Data Analyst'].copy()
df_data_scientist = df[df['job_title'] == 'Data Scientist'].copy()
df_combined = pd.concat([df_data_analyst, df_data_scientist],ignore_index=True)
df_combined
# Out:
#       job_title_short       job_title                      job_location  \
# 0        Data Analyst    Data Analyst      Guadalajara, Jalisco, Mexico
# 1        Data Analyst    Data Analyst                    Warsaw, Poland
# 2        Data Analyst    Data Analyst                    Des Moines, IA
# 3        Data Analyst    Data Analyst                         Singapore
# 4        Data Analyst    Data Analyst                         Tampa, FL
# ...               ...             ...                               ...
# 84487  Data Scientist  Data Scientist                 Helsinki, Finland
# 84488  Data Scientist  Data Scientist                         Tempe, AZ
# 84489  Data Scientist  Data Scientist                   Santiago, Chile
# 84490  Data Scientist  Data Scientist  San Vicente, Antioquia, Colombia
# 84491  Data Scientist  Data Scientist       Kolkata, West Bengal, India
#
#                                              job_via job_schedule_type  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Concat Monthly Postings (2.8.2)

# %%
df_oct = df[df['job_posted_date'].dt.month == 10].copy()
df_nov = df[df['job_posted_date'].dt.month == 11].copy()
df_dec = df[df['job_posted_date'].dt.month == 12].copy()
df_combined_q4 = pd.concat([df_oct, df_nov, df_dec], ignore_index=True)
print(df_combined_q4)
df_combined_q4['job_posted_date'].dt.strftime('%b').value_counts().plot(kind='bar')
# Out:
#          job_title_short                                          job_title  \
# 0          Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 1          Data Engineer                                      Data Engineer
# 2           Data Analyst                                       Data Analyst
# 3           Data Analyst                           Stage - Data Analyst F/H
# 4           Data Analyst  Data Analyst (Bangkok Based, relocation provided)
# ...                  ...                                                ...
# 187359     Data Engineer                                      Data Engineer
# 187360     Data Engineer                                      Data Engineer
# 187361      Data Analyst                                  Data Analyst Lead
# 187362  Business Analyst         Business Analysis and Intelligence Manager
# 187363    Cloud Engineer                             Engineer 3, Facilities
#
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Concat Job Types (2.8.3)

# %%
df_full_time = df[df['job_schedule_type'] == 'Full-time'].copy()
df_part_time = df[df['job_schedule_type'] == 'Part-time'].copy()
df_combined_schedule = pd.concat([df_full_time, df_part_time], ignore_index=True)
df_combined_schedule['job_schedule_type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_schedule_type'>

# %% [markdown]
# ---
